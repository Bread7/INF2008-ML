# %% [markdown]
# ## Week 03 INF2008 Lab: Linear Regression Case Study

# %% [markdown]
# We import some libaries below.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Upload the csv data file into the Google colab file system.
#
# Create a dataframe (dataset) by reading the CSV file: 'resale-flat-prices-based-on-registration-date-from-jan-2017-onwards.csv'

# %%
url = 'https://raw.githubusercontent.com/Bread7/INF2008-ML/main/resale-flat-prices-based-on-registration-date-from-jan-2017-onwards.csv'
df = pd.read_csv(url)

# %% [markdown]
# View the top 5 and bottom 5 rows.

# %%
combine = pd.concat([df.head(), df.tail()])
combine
# Out:
#          month        town         flat_type block        street_name  \
# 0      2017-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1      2017-01  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2      2017-01  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3      2017-01  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4      2017-01  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# 82796  2020-10      YISHUN         EXECUTIVE   834       YISHUN ST 81
# 82797  2020-10      YISHUN         EXECUTIVE   877       YISHUN ST 81
# 82798  2020-10      YISHUN         EXECUTIVE   877       YISHUN ST 81
# 82799  2020-10      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
# 82800  2020-10      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# 0         10 TO 12            44.0          Improved                 1979
# 1         01 TO 03            67.0    New Generation                 1978
# 2         01 TO 03            67.0    New Generation                 1980
# 3         04 TO 06            68.0    New Generation                 1980
# 4         01 TO 03            67.0    New Generation                 1980
# 82796     04 TO 06           146.0        Maisonette                 1988
# 82797     01 TO 03           145.0        Maisonette                 1987
# 82798     07 TO 09           142.0         Apartment                 1987
# 82799     10 TO 12           164.0  Multi Generation                 1987
# 82800     10 TO 12           171.0  Multi Generation                 1987
#
#           remaining_lease  resale_price
# 0      61 years 04 months      232000.0
# 1      60 years 07 months      250000.0
# 2      62 years 05 months      262000.0
# 3       62 years 01 month      265000.0
# 4      62 years 05 months      265000.0
# 82796  66 years 03 months      680000.0
# 82797  66 years 02 months      618000.0
# 82798  66 years 02 months      670000.0
# 82799  66 years 02 months      750000.0
# 82800  66 years 02 months      780000.0

# %% [markdown]
# View only the top five rows.

# %%
df.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
# 3            68.0  New Generation                 1980   62 years 01 month
# 4            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# 4      265000.0

# %% [markdown]
# View only the bottom five rows.

# %%
df.tail()
# Out:
#          month    town         flat_type block   street_name storey_range  \
# 82796  2020-10  YISHUN         EXECUTIVE   834  YISHUN ST 81     04 TO 06
# 82797  2020-10  YISHUN         EXECUTIVE   877  YISHUN ST 81     01 TO 03
# 82798  2020-10  YISHUN         EXECUTIVE   877  YISHUN ST 81     07 TO 09
# 82799  2020-10  YISHUN  MULTI-GENERATION   633  YISHUN ST 61     10 TO 12
# 82800  2020-10  YISHUN  MULTI-GENERATION   633  YISHUN ST 61     10 TO 12
#
#        floor_area_sqm        flat_model  lease_commence_date  \
# 82796           146.0        Maisonette                 1988
# 82797           145.0        Maisonette                 1987
# 82798           142.0         Apartment                 1987
# 82799           164.0  Multi Generation                 1987
# 82800           171.0  Multi Generation                 1987
#
#           remaining_lease  resale_price
# 82796  66 years 03 months      680000.0
# 82797  66 years 02 months      618000.0
# 82798  66 years 02 months      670000.0
# 82799  66 years 02 months      750000.0
# 82800  66 years 02 months      780000.0

# %% [markdown]
# View the columns in the dataframe.

# %%
df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date',
#        'remaining_lease', 'resale_price'],
#       dtype='object')

# %% [markdown]
# Check the data types of the columns (hint, use the dtypes property).

# %%
df.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# remaining_lease         object
# resale_price           float64
# dtype: object

# %% [markdown]
# Check if there is any null or missing data in the dataframe.

# %%
df.isnull()
# Out:
#        month   town  flat_type  block  street_name  storey_range  \
# 0      False  False      False  False        False         False
# 1      False  False      False  False        False         False
# 2      False  False      False  False        False         False
# 3      False  False      False  False        False         False
# 4      False  False      False  False        False         False
# ...      ...    ...        ...    ...          ...           ...
# 82796  False  False      False  False        False         False
# 82797  False  False      False  False        False         False
# 82798  False  False      False  False        False         False
# 82799  False  False      False  False        False         False
# 82800  False  False      False  False        False         False
#
#        floor_area_sqm  flat_model  lease_commence_date  remaining_lease  \
# 0               False       False                False            False
# 1               False       False                False            False
# 2               False       False                False            False
# 3               False       False                False            False
# 4               False       False                False            False
# ...               ...         ...                  ...              ...
# 82796           False       False                False            False
# 82797           False       False                False            False
# 82798           False       False                False            False
# 82799           False       False                False            False
# 82800           False       False                False            False
#
#        resale_price
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 82796         False
# 82797         False
# 82798         False
# 82799         False
# 82800         False
#
# [82801 rows x 11 columns]

# %% [markdown]
# Use the describe function to find out what are some of the basic statistical metrics in the numberical columns of the dataset.

# %%
df.describe()
# Out:
#        floor_area_sqm  lease_commence_date  resale_price
# count    82801.000000         82801.000000  8.280100e+04
# mean        97.661664          1994.199345  4.404444e+05
# std         24.290822            12.891561  1.537263e+05
# min         31.000000          1966.000000  1.400000e+05
# 25%         82.000000          1984.000000  3.300000e+05
# 50%         95.000000          1994.000000  4.100000e+05
# 75%        113.000000          2003.000000  5.150000e+05
# max        249.000000          2019.000000  1.258000e+06

# %% [markdown]
# This describes the dataset for all the columns. It is useful to find number of  unique values for individual columns.

# %%
include = ['object', 'float', 'int']
df.describe(include=include)
# Out:
#           month      town flat_type  block     street_name storey_range  \
# count     82801     82801     82801  82801           82801        82801
# unique       46        26         7   2457             549           17
# top     2018-07  SENGKANG    4 ROOM      2  YISHUN RING RD     04 TO 06
# freq       2539      6659     34288    280            1277        19273
# mean        NaN       NaN       NaN    NaN             NaN          NaN
# std         NaN       NaN       NaN    NaN             NaN          NaN
# min         NaN       NaN       NaN    NaN             NaN          NaN
# 25%         NaN       NaN       NaN    NaN             NaN          NaN
# 50%         NaN       NaN       NaN    NaN             NaN          NaN
# 75%         NaN       NaN       NaN    NaN             NaN          NaN
# max         NaN       NaN       NaN    NaN             NaN          NaN
#
#         floor_area_sqm flat_model  lease_commence_date     remaining_lease  \
# count     82801.000000      82801         82801.000000               82801
# unique             NaN         20                  NaN                 625
# top                NaN    Model A                  NaN  94 years 09 months
# freq               NaN      27069                  NaN                 648
# mean         97.661664        NaN          1994.199345                 NaN
# std          24.290822        NaN            12.891561                 NaN
# min          31.000000        NaN          1966.000000                 NaN
# 25%          82.000000        NaN          1984.000000                 NaN
# 50%          95.000000        NaN          1994.000000                 NaN
# 75%         113.000000        NaN          2003.000000                 NaN
# max         249.000000        NaN          2019.000000                 NaN
#
#         resale_price
# count   8.280100e+04
# unique           NaN
# top              NaN
# freq             NaN
# mean    4.404444e+05
# std     1.537263e+05
# min     1.400000e+05
# 25%     3.300000e+05
# 50%     4.100000e+05
# 75%     5.150000e+05
# max     1.258000e+06

# %%
# Show correlation heat map and matrix
corrmat = df.corr()
sns.heatmap(corrmat,annot = True)
plt.show()
# Out:
# <ipython-input-11-6f08bf24c7f1>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# **Descide columns to drop / modify / categorise**

# %% [markdown]
# Columns to drop

# %% [markdown]
# #### Analyze Street name and lease commence date

# %% [markdown]
# For this exercise, we will be dropping the street name. However in your own analysis, you may want to consider using the street name as one of the x variables as well. Especially the distance from the address to the nearest MRT, or Primary school.
#
# Drop also the lease commence date for this anaylsis. It doesn't cause any harm if you keep it. Just that it is another column to engineer and we want to keep things a bit simpler for this lab.
#
# Drop columns "street_name", 'block' and "lease_commence_data".

# %%
df.drop(['street_name','lease_commence_date', 'block'], axis=1, inplace=True)
df.head(5)
# Out:
#      month        town flat_type storey_range  floor_area_sqm      flat_model  \
# 0  2017-01  ANG MO KIO    2 ROOM     10 TO 12            44.0        Improved
# 1  2017-01  ANG MO KIO    3 ROOM     01 TO 03            67.0  New Generation
# 2  2017-01  ANG MO KIO    3 ROOM     01 TO 03            67.0  New Generation
# 3  2017-01  ANG MO KIO    3 ROOM     04 TO 06            68.0  New Generation
# 4  2017-01  ANG MO KIO    3 ROOM     01 TO 03            67.0  New Generation
#
#       remaining_lease  resale_price
# 0  61 years 04 months      232000.0
# 1  60 years 07 months      250000.0
# 2  62 years 05 months      262000.0
# 3   62 years 01 month      265000.0
# 4  62 years 05 months      265000.0

# %% [markdown]
# Typically we may want to check the numerical data for outliers but we are ignoring those for now.

# %% [markdown]
# #### Analyze month.

# %% [markdown]
# This is the resale registration date in YYYY-MM format.
#
# Example: 2017-01
#
# For simplicity, ignore the month part and copy only the year part to a new column 'reg_year'. After that remove the month column.

# %%
new_df = df.assign(reg_year=df["month"].str[:4])
new_df
# Out:
#          month        town         flat_type storey_range  floor_area_sqm  \
# 0      2017-01  ANG MO KIO            2 ROOM     10 TO 12            44.0
# 1      2017-01  ANG MO KIO            3 ROOM     01 TO 03            67.0
# 2      2017-01  ANG MO KIO            3 ROOM     01 TO 03            67.0
# 3      2017-01  ANG MO KIO            3 ROOM     04 TO 06            68.0
# 4      2017-01  ANG MO KIO            3 ROOM     01 TO 03            67.0
# ...        ...         ...               ...          ...             ...
# 82796  2020-10      YISHUN         EXECUTIVE     04 TO 06           146.0
# 82797  2020-10      YISHUN         EXECUTIVE     01 TO 03           145.0
# 82798  2020-10      YISHUN         EXECUTIVE     07 TO 09           142.0
# 82799  2020-10      YISHUN  MULTI-GENERATION     10 TO 12           164.0
# 82800  2020-10      YISHUN  MULTI-GENERATION     10 TO 12           171.0
#
#              flat_model     remaining_lease  resale_price reg_year
# 0              Improved  61 years 04 months      232000.0     2017
# 1        New Generation  60 years 07 months      250000.0     2017
# 2        New Generation  62 years 05 months      262000.0     2017
# 3        New Generation   62 years 01 month      265000.0     2017
# 4        New Generation  62 years 05 months      265000.0     2017
# ...                 ...                 ...           ...      ...
# 82796        Maisonette  66 years 03 months      680000.0     2020
# 82797        Maisonette  66 years 02 months      618000.0     2020
# 82798         Apartment  66 years 02 months      670000.0     2020
# 82799  Multi Generation  66 years 02 months      750000.0     2020
# 82800  Multi Generation  66 years 02 months      780000.0     2020
#
# [82801 rows x 9 columns]

# %% [markdown]
# Drop month column.

# %%
df2 = new_df.drop(columns='month')
df2
# Out:
#              town         flat_type storey_range  floor_area_sqm  \
# 0      ANG MO KIO            2 ROOM     10 TO 12            44.0
# 1      ANG MO KIO            3 ROOM     01 TO 03            67.0
# 2      ANG MO KIO            3 ROOM     01 TO 03            67.0
# 3      ANG MO KIO            3 ROOM     04 TO 06            68.0
# 4      ANG MO KIO            3 ROOM     01 TO 03            67.0
# ...           ...               ...          ...             ...
# 82796      YISHUN         EXECUTIVE     04 TO 06           146.0
# 82797      YISHUN         EXECUTIVE     01 TO 03           145.0
# 82798      YISHUN         EXECUTIVE     07 TO 09           142.0
# 82799      YISHUN  MULTI-GENERATION     10 TO 12           164.0
# 82800      YISHUN  MULTI-GENERATION     10 TO 12           171.0
#
#              flat_model     remaining_lease  resale_price reg_year
# 0              Improved  61 years 04 months      232000.0     2017
# 1        New Generation  60 years 07 months      250000.0     2017
# 2        New Generation  62 years 05 months      262000.0     2017
# 3        New Generation   62 years 01 month      265000.0     2017
# 4        New Generation  62 years 05 months      265000.0     2017
# ...                 ...                 ...           ...      ...
# 82796        Maisonette  66 years 03 months      680000.0     2020
# 82797        Maisonette  66 years 02 months      618000.0     2020
# 82798         Apartment  66 years 02 months      670000.0     2020
# 82799  Multi Generation  66 years 02 months      750000.0     2020
# 82800  Multi Generation  66 years 02 months      780000.0     2020
#
# [82801 rows x 8 columns]

# %% [markdown]
# Split 'remaining_lease' to 'remain_lease_year' and 'remain_lease_month'

# %%
df3 = df2.assign(remain_lease_year=df2['remaining_lease'].str[:2])
df3 = df3.assign(remain_lease_month=df3['remaining_lease'].str[-9:])
df3
# Out:
#              town         flat_type storey_range  floor_area_sqm  \
# 0      ANG MO KIO            2 ROOM     10 TO 12            44.0
# 1      ANG MO KIO            3 ROOM     01 TO 03            67.0
# 2      ANG MO KIO            3 ROOM     01 TO 03            67.0
# 3      ANG MO KIO            3 ROOM     04 TO 06            68.0
# 4      ANG MO KIO            3 ROOM     01 TO 03            67.0
# ...           ...               ...          ...             ...
# 82796      YISHUN         EXECUTIVE     04 TO 06           146.0
# 82797      YISHUN         EXECUTIVE     01 TO 03           145.0
# 82798      YISHUN         EXECUTIVE     07 TO 09           142.0
# 82799      YISHUN  MULTI-GENERATION     10 TO 12           164.0
# 82800      YISHUN  MULTI-GENERATION     10 TO 12           171.0
#
#              flat_model     remaining_lease  resale_price reg_year  \
# 0              Improved  61 years 04 months      232000.0     2017
# 1        New Generation  60 years 07 months      250000.0     2017
# 2        New Generation  62 years 05 months      262000.0     2017
# 3        New Generation   62 years 01 month      265000.0     2017
# 4        New Generation  62 years 05 months      265000.0     2017
# ...                 ...                 ...           ...      ...
# 82796        Maisonette  66 years 03 months      680000.0     2020
# 82797        Maisonette  66 years 02 months      618000.0     2020
# 82798         Apartment  66 years 02 months      670000.0     2020
# 82799  Multi Generation  66 years 02 months      750000.0     2020
# 82800  Multi Generation  66 years 02 months      780000.0     2020
#
#       remain_lease_year remain_lease_month
# 0                    61          04 months
# 1                    60          07 months
# 2                    62          05 months
# 3                    62           01 month
# 4                    62          05 months
# ...                 ...                ...
# 82796                66          03 months
# 82797                66          02 months
# 82798                66          02 months
# 82799                66          02 months
# 82800                66          02 months
#
# [82801 rows x 10 columns]

# %% [markdown]
# remove columns: 'remaining_lease' and 'remain_lease_month'

# %%
df3.drop(columns=['remain_lease_year', 'remain_lease_month'])
# Out:
#              town         flat_type storey_range  floor_area_sqm  \
# 0      ANG MO KIO            2 ROOM     10 TO 12            44.0
# 1      ANG MO KIO            3 ROOM     01 TO 03            67.0
# 2      ANG MO KIO            3 ROOM     01 TO 03            67.0
# 3      ANG MO KIO            3 ROOM     04 TO 06            68.0
# 4      ANG MO KIO            3 ROOM     01 TO 03            67.0
# ...           ...               ...          ...             ...
# 82796      YISHUN         EXECUTIVE     04 TO 06           146.0
# 82797      YISHUN         EXECUTIVE     01 TO 03           145.0
# 82798      YISHUN         EXECUTIVE     07 TO 09           142.0
# 82799      YISHUN  MULTI-GENERATION     10 TO 12           164.0
# 82800      YISHUN  MULTI-GENERATION     10 TO 12           171.0
#
#              flat_model     remaining_lease  resale_price reg_year
# 0              Improved  61 years 04 months      232000.0     2017
# 1        New Generation  60 years 07 months      250000.0     2017
# 2        New Generation  62 years 05 months      262000.0     2017
# 3        New Generation   62 years 01 month      265000.0     2017
# 4        New Generation  62 years 05 months      265000.0     2017
# ...                 ...                 ...           ...      ...
# 82796        Maisonette  66 years 03 months      680000.0     2020
# 82797        Maisonette  66 years 02 months      618000.0     2020
# 82798         Apartment  66 years 02 months      670000.0     2020
# 82799  Multi Generation  66 years 02 months      750000.0     2020
# 82800  Multi Generation  66 years 02 months      780000.0     2020
#
# [82801 rows x 8 columns]

# %% [markdown]
# We now need to fix a lot of columns that are non numeric. From the dataframe above, they are:
# *   town
# *   flat_type
# *   block
# *   storey_range
# *   flat_model

# %% [markdown]
# View categories in 'flat_type'

# %%
df3['flat_type'].unique()
# Out:
# array(['2 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', 'EXECUTIVE', '1 ROOM',
#        'MULTI-GENERATION'], dtype=object)

# %% [markdown]
# View categories in 'town' and count the number of unique categories in town.

# %%
df3['town'].unique()
df3['town'].unique().size
# Out:
# 26

# %% [markdown]
# As this is a lab on linear regression, non ordinal categorical variables do not work very well. Although town and flat_model has has an ordinal arrangement, you need to find out the order from other data sources. I will leave you to carry out this step. For now, we will remove the flat_model, town and flat_type.
#
# *   flat_type
# *   flat_model
# *   town

# %%
# Out:
#   storey_range  floor_area_sqm  resale_price  reg_year  remain_lease_year
# 0     10 TO 12            44.0      232000.0      2017                 61
# 1     01 TO 03            67.0      250000.0      2017                 60
# 2     01 TO 03            67.0      262000.0      2017                 62
# 3     04 TO 06            68.0      265000.0      2017                 62
# 4     01 TO 03            67.0      265000.0      2017                 62

# %% [markdown]
# ** Ordinal data have to be ranked and not categorized**
#
# The last is storey_range. We will carry out some label encoding and check that the encoding done is correct.

# %%
storey_range_unique = df['storey_range'].unique()
storey_range_unique
# Out:
# array(['10 TO 12', '01 TO 03', '04 TO 06', '07 TO 09', '13 TO 15',
#        '19 TO 21', '22 TO 24', '16 TO 18', '34 TO 36', '28 TO 30',
#        '37 TO 39', '49 TO 51', '25 TO 27', '40 TO 42', '31 TO 33',
#        '46 TO 48', '43 TO 45'], dtype=object)

# %% [markdown]
# Check the ordering of the encoded values are correct.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
mapped = le.fit_transform(storey_range_unique)

mapping = dict(zip(mapped, storey_range_unique))
sorted_dict = dict(sorted(mapping.items()))
print(sorted_dict)
# Out:
# {0: '01 TO 03', 1: '04 TO 06', 2: '07 TO 09', 3: '10 TO 12', 4: '13 TO 15', 5: '16 TO 18', 6: '19 TO 21', 7: '22 TO 24', 8: '25 TO 27', 9: '28 TO 30', 10: '31 TO 33', 11: '34 TO 36', 12: '37 TO 39', 13: '40 TO 42', 14: '43 TO 45', 15: '46 TO 48', 16: '49 TO 51'}

# %%
df['storey_range_cat'] = le.transform(df['storey_range'])
df.head(5)
# Out:
#   storey_range  floor_area_sqm  resale_price  reg_year  remain_lease_year  \
# 0     10 TO 12            44.0      232000.0      2017                 61
# 1     01 TO 03            67.0      250000.0      2017                 60
# 2     01 TO 03            67.0      262000.0      2017                 62
# 3     04 TO 06            68.0      265000.0      2017                 62
# 4     01 TO 03            67.0      265000.0      2017                 62
#
#    storey_range_cat
# 0                 3
# 1                 0
# 2                 0
# 3                 1
# 4                 0

# %% [markdown]
# Drop storey range column.

# %%
# Out:
#    floor_area_sqm  resale_price  reg_year  remain_lease_year  storey_range_cat
# 0            44.0      232000.0      2017                 61                 3
# 1            67.0      250000.0      2017                 60                 0
# 2            67.0      262000.0      2017                 62                 0
# 3            68.0      265000.0      2017                 62                 1
# 4            67.0      265000.0      2017                 62                 0

# %% [markdown]
# Show the correlation mapping of the dataframe.

# %% [markdown]
# If two columns are highly correlated, drop one (probably the category column)

# %% [markdown]
# **Model the data**

# %% [markdown]
# Identify x and y variables.

# %%
# X: Input columns
# y: Target column

feature_cols = ['floor_area_sqm','storey_range_cat', 'reg_year', 'remain_lease_year']

X = df[feature_cols]
y = df[['resale_price']].copy()

# print columns in X
X.columns
# Out:
# Index(['floor_area_sqm', 'storey_range_cat', 'reg_year', 'remain_lease_year'], dtype='object')

# %%
# Print y column name
y.columns
# Out:
# Index(['resale_price'], dtype='object')

# %% [markdown]
# Split dataset for train and test

# %% [markdown]
# Import random and set a random seed of 15

# %% [markdown]
# Import library for splitting the dataset

# %% [markdown]
# Split the data into training data (70%) and testing data (30%).

# %%
# Out:
# (57960, 4) (24841, 4)

# %% [markdown]
# Modelling / Learning

# %% [markdown]
# Import the linear model from sklearn.

# %% [markdown]
# Train the model.

# %%
# Out:
# LinearRegression()

# %% [markdown]
# Test it on X_test and print out the first 20 values from the predicted y variables.

# %%
# Out:
# [[375530.41362948]
#  [302928.31309693]
#  [406338.73879118]
#  [606011.01831107]
#  [436296.04805597]
#  [410761.18160728]
#  [418275.01499637]
#  [692847.66726074]
#  [401779.59523641]
#  [316161.78517413]
#  [429013.80971712]
#  [413503.07232432]
#  [598053.74698908]
#  [605816.57954634]
#  [466227.20642203]
#  [230042.4962889 ]
#  [463398.86531021]
#  [718729.20644939]
#  [683542.64685886]
#  [417600.11472964]]

# %% [markdown]
# Evaluate: Performance Metrics

# %% [markdown]
# Print out the coefficients and the y intercept.

# %%
# Out:
# [-1745445.15097073]
# [[ 3834.29580815 26433.05056528   811.5159316   1554.72403077]]

# %% [markdown]
# # Multilinear Regression Equation

# %% [markdown]
# Import the metrics library from sklearn.

# %% [markdown]
# Calculate the RMSE. You should get 102774

# %%
# Out:
# 102774.46411818957

# %%
sns.regplot(x= y_test, y=pred_outputs, line_kws={"color": "red"})
# Out:
# <Axes: xlabel='resale_price'>
